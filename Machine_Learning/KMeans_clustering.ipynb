# %% [markdown]
# # K-means Clustering
# K-means clustering is one of the most commonly used clustering algorithms. It
# is an iterative algorithm that helps you to find a number of clusters for a given
# dataset.

# %% [markdown]
# The following are the steps of the algorithm:
# 1. Randomly select K points as the center of K clusters, called centroids.
# 2. Calculate the distance between all centroids and the data points. Separate data points into different clusters according to the distances.
# 3. Calculate the mean of all the data of each cluster and move the centroids to the new center of the cluster.
# 4. Repeat steps 2 and 3 for a specified number of iterations until all the clusters are clearly separated.

# %% [markdown]
# Example 1 shows a simple example of Python K-means
# clustering. It first creates a Numpy array named x, which contains two groups of values. It then
# performs the two-component K-means clustering by using the functions KMeans()
# and fit(). Finally, it displays the clustering results: the labels of the two clusters
# and centers of the two clusters and predicts a result for a given sample.

# %%
# Example 1 K-means Clustering
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2, 3], [1, 4, 2], [1, 0, 3], \
[10, 2, 4], [9, 4, 3], [11, 0, 2]])
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
print(kmeans.labels_)
print(kmeans.cluster_centers_)
print(kmeans.predict([[12, 3, 1]]))
# Out:
# [1 1 1 0 0 0]
# [[10.          2.          3.        ]
#  [ 1.          2.          2.66666667]]
# [0]
